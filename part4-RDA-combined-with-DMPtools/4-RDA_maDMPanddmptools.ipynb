# %% [markdown]
# # 1. JSON-style schema skeleton

# %%
#Import libraries
import requests
import xml.etree.ElementTree as ET
import json
from jsonschema import validate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 #Import libraries
# ----> 2 import requests
#       3 import xml.etree.ElementTree as ET
#       4 import json
#
# ModuleNotFoundError: No module named 'requests'

# %%
# Final corrected maDMP schema skeleton
dmp_schema_skeleton = {
    "$schema": "./JSON-schema/1.2/maDMP-schema-1.2.json",
    "dmp": {
        "dmp_id": {
            "identifier": "",
            "type": ""
        },
        "title": "",
        "description": "",
        "created": "",
        "modified": "",
        "language": "",
        "ethical_issues_exist": "",
        "ethical_issues_description": "",
        "ethical_issues_report": "",

        "contact": {
            "name": "",
            "mbox": "",
            "contact_id": {
                "identifier": "",
                "type": ""
            },
            "affiliation": [
                {
                    "name": "",
                    "affiliation_id": {
                        "identifier": "",
                        "type": ""
                    }
                }
            ]
        },

        "contributor": [
            {
                "name": "",
                "mbox": "",
                "role": [],
                "contributor_id": {
                    "identifier": "",
                    "type": ""
                },
                "affiliation": [
                    {
                        "name": "",
                        "affiliation_id": {
                            "identifier": "",
                            "type": ""
                        }
                    }
                ]
            }
        ],

        "cost": [
            {
                "title": "",
                "description": "",
                "value": 0,
                "currency_code": ""
            }
        ],

        "project": [
            {
                "title": "",
                "description": "",
                "start": "",
                "end": "",
                "project_id": [
                    {
                        "identifier": "",
                        "type": ""
                    }
                ],
                "funding": [
                    {
                        "funder_name": "",
                        "funder_id": {
                            "identifier": "",
                            "type": ""
                        },
                        "grant_id": {
                            "identifier": "",
                            "type": ""
                        },
                        "funding_status": ""
                    }
                ]
            }
        ],

        "dataset": [
            {
                "dataset_id": {
                    "identifier": "",
                    "type": ""
                },
                "title": "",
                "description": "",
                "type": "",
                "issued": "",
                "language": "",
                "keyword": [],
                "is_reused": False,
                "personal_data": "",
                "sensitive_data": "",
                "preservation_statement": "",
                "data_quality_assurance": [],
                "security_and_privacy": [
                    {
                        "title": "",
                        "description": ""
                    }
                ],
                "rights": "",

                "alternate_identifier": [
                    {
                        "identifier": "",
                        "type": ""
                    }
                ],

                "creator": [
                    {
                        "name": "",
                        "mbox": "",
                        "creator_id": {
                            "identifier": "",
                            "type": ""
                        },
                        "affiliation": [
                            {
                                "name": "",
                                "affiliation_id": {
                                    "identifier": "",
                                    "type": ""
                                }
                            }
                        ]
                    }
                ],

                "distribution": [
                    {
                        "title": "",
                        "description": "",
                        "access_url": "",
                        "available_until": "",
                        "byte_size": 0,
                        "data_access": "",
                        "download_url": "",
                        "format": [],
                        "issued": "",
                        "license": [
                            {
                                "license_ref": "",
                                "start_date": ""
                            }
                        ],
                        "host": {
                            "title": "",
                            "url": "",
                            "description": "",
                            "availability": "",
                            "backup_frequency": "",
                            "backup_type": "",
                            "certified_with": "",
                            "geo_location": "",
                            "host_id": {
                                "identifier": "",
                                "type": ""
                            },
                            "pid_system": [],
                            "storage_type": "",
                            "support_versioning": ""
                        }
                    }
                ],

                "metadata": [
                    {
                        "description": "",
                        "language": "",
                        "metadata_standard_id": [
                            {
                                "identifier": "",
                                "type": ""
                            }
                        ]
                    }
                ],

                "related_identifier": [
                    {
                        "identifier": "",
                        "type": "",
                        "relation_type": "",
                        "metadata_scheme": "",
                        "scheme_uri": "",
                        "scheme_type": "",
                        "resource_type": ""
                    }
                ],

                "technical_resource": [
                    {
                        "name": "",
                        "description": "",
                        "technical_resource_id": [
                            {
                                "identifier": "",
                                "type": ""
                            }
                        ]
                    }
                ]
            }
        ],

        "alternate_identifier": [
            {
                "identifier": "",
                "type": ""
            }
        ],

        "related_identifier": [
            {
                "identifier": "",
                "type": "",
                "relation_type": "",
                "metadata_scheme": "",
                "scheme_uri": "",
                "scheme_type": "",
                "resource_type": ""
            }
        ]
    }
}

print("Final corrected schema defined.")
# Out:
# Final corrected schema defined.

# %%
# Step 2 — save the schema
with open("dmp_schema_skeleton.json", "w", encoding="utf-8") as f:
    json.dump(dmp_schema_skeleton, f, indent=2, ensure_ascii=False)

print("Saved: dmp_schema_skeleton.json")
# Out:
# Saved: dmp_schema_skeleton.json

# %%
dmp1_original= {
    "$schema": "./JSON-schema/1.2/maDMP-schema-1.2.json",
    "dmp": {
        "dmp_id": {
            "identifier": "https://doi.org/10.48321/D1BS7N",
            "type": "doi"
        },
        "title": "Effects of Placental Dysfunction on Brain Growth in Congenital Heart Disease",
        "description": "The proposed project will involve human participants and will acquire demographic, clinical, fetal/placental magnetic resonance imaging (MRI), genomic, and placental tissue data from 225 pregnant women with a fetal diagnosis of CHD and 115 pregnant women with a healthy fetus. This study involves eight co-investigators from three sites, Washington University in St. Louis (WUSTL), Boston Children's Hospital (BCH), and The Hospital for Sick Children (SickKids).",
        "created": None,
        "modified": "01-24-2024",
        "language": None,
        "ethical_issues_exist": "yes",
        "ethical_issues_description": "The project involves human participants. Informed consent documents will include language describing plans for data management and sharing of data, describing the motivation for sharing, and explaining that personal identifying information will be removed. Privacy and confidentiality protections consistent with applicable federal, Tribal, state, and local laws, regulations, and policies will be followed. Data will be deidentified by removing all 18 HIPAA identifiers prior to sharing, and the study will have a Certificate of Confidentiality from NIH.",
        "ethical_issues_report": None,

        "contact": {
            "name": "Cynthia Ortinau",
            "mbox": None,
            "contact_id": {
                "identifier": "0000-0003-0851-0796",
                "type": "orcid"
            },
            "affiliation": [
                {
                    "name": "Washington University in St. Louis",
                    "affiliation_id": {
                        "identifier": None,
                        "type": None
                    }
                }
            ]
        },

        "contributor": [
            {
                "name": "Cynthia Ortinau",
                "mbox": None,
                "role": [
                    "LeadPI",
                    "ProjectAdministration",
                    "DataManagement"
                ],
                "contributor_id": {
                    "identifier": "0000-0003-0851-0796",
                    "type": "orcid"
                },
                "affiliation": [
                    {
                        "name": "Washington University in St. Louis",
                        "affiliation_id": {
                            "identifier": None,
                            "type": None
                        }
                    }
                ]
            }
        ],

        "cost": [
            {
                "title": None,
                "description": None,
                "value": None,
                "currency_code": None
            }
        ],

        "project": [
            {
                "title": "Effects of Placental Dysfunction on Brain Growth in Congenital Heart Disease",
                "description": "Study across Washington University in St. Louis, Boston Children's Hospital, and The Hospital for Sick Children involving demographic, clinical, MRI, genomic, and placental tissue data from pregnant women with fetal CHD and healthy fetuses.",
                "start": " 09-01-2023",
                "end": " 08-31-2028",
                "project_id": [
                    {
                        "identifier": None,
                        "type": None
                    }
                ],
                "funding": [
                    {
                        "funder_name": "National Institutes of Health",
                        "funder_id": {
                            "identifier": None,
                            "type": None
                        },
                        "grant_id": {
                            "identifier": "PA-20-185",
                            "type": "funding_opportunity_number"
                        },
                        "funding_status": None
                    }
                ]
            }
        ],

        "dataset": [
            {
                "dataset_id": {
                    "identifier": None,
                    "type": None
                },
                "title": "Demographic and clinical data",
                "description": "Demographic data include maternal age, race, ethnicity, fetal sex, and socioeconomics such as zip code and insurance type. Clinical data include cardiac diagnosis, details of pregnancy and fetal complications, and details of infant postnatal course. Demographic and clinical data will be captured by each site into the REDCap secure electronic data capture system.",
                "type": "demographic; clinical",
                "issued": None,
                "language": None,
                "keyword": [
                    "demographic data",
                    "clinical data",
                    "REDCap",
                    "human participants"
                ],
                "is_reused": None,
                "personal_data": "yes",
                "sensitive_data": "yes",
                "preservation_statement": "Demographic and clinical data entered into the REDCap EDC system will be cleaned, de-identified, preserved and shared.",
                "data_quality_assurance": [
                    "Dr. Ortinau will meet monthly with key study personnel to ensure the timeliness of data entry and review data to ensure the quality of data entry."
                ],
                "security_and_privacy": [
                    {
                        "title": "Controlled access and de-identification",
                        "description": "Each user will be given role specific access to the EDC system, and access will be controlled by granting users individual usernames and passwords. Appropriate measures such as assigning a study identification number and removal of all dates will be used for data de-identification and sharing."
                    }
                ],
                "rights": "Data will be made publicly available with controlled access under a Data Use Agreement to ensure the safety of participants' data.",
                "alternate_identifier": [
                    {
                        "identifier": None,
                        "type": None
                    }
                ],
                "creator": [
                    {
                        "name": "Cynthia Ortinau",
                        "mbox": None,
                        "creator_id": {
                            "identifier": "0000-0003-0851-0796",
                            "type": "orcid"
                        },
                        "affiliation": [
                            {
                                "name": "Washington University in St. Louis",
                                "affiliation_id": {
                                    "identifier": None,
                                    "type": None
                                }
                            }
                        ]
                    }
                ],
                
                 "distribution": [
                    {
                        "title": "De-identified demographic and clinical data distribution",
                        "description": "All de-identified demographic and clinical data will be shared via the institutional repository Digital Commons@Becker. Data will be made publicly available with controlled access under Data Use Agreement to ensure the safety of participants' data.",
                        "access_url": None,
                        "available_until": None,
                        "byte_size": 5368709120,
                        "data_access": "Controlled access under Data Use Agreement",
                        "download_url": None,
                        "format": [],
                        "issued": None,
                        "license": [
                            {
                                "license_ref": None,
                                "start_date": None
                            }
                        ],
                        "host": {
                            "title": "Digital Commons@Becker",
                            "url": None,
                            "description": "Digital Commons@Becker provides metadata, persistent identifiers (DOIs), and long-term access. It is administered and maintained by the Bernard Becker Medical Library, is hosted by bepress, is backed up by S3 cloud storage, conducts regular audits for fixity and authenticity, and has plans in instances of repository host change.",
                            "availability": "Long-term access",
                            "backup_frequency": None,
                            "backup_type": "S3 cloud storage backup",
                            "certified_with":  "Washington University School of Medicine in St. Louis and is administered and maintained by the Bernard Becker Medical Library." ,
                            "geo_location": None,
                            "host_id": {
                                "identifier": "DigitalCommons@Becker",
                                "type": None
                            },
                            "pid_system": "DOI",
                            "storage_type": "repository",
                            "support_versioning": None
                        }
                    }
                ],
                "metadata": [
                    {
                        "description": "A data dictionary will be generated and deposited into a repository along with all shared datasets. A README file will also be generated and deposited into the repository and will include instructions for data analysis.",
                        "language": "en",
                        "metadata_standard_id": [
                            {
                                "identifier": None,
                                "type": None
                            }
                        ]
                    }
                ],
                "related_identifier": [
                    {
                        "identifier": None,
                        "type": None,
                        "relation_type": None,
                        "metadata_scheme": None,
                        "scheme_uri": None,
                        "scheme_type": None,
                        "resource_type": None
                    }
                ],
                "technical_resource": [
                    {
                        "name": None,
                        "description": None,
                        "technical_resource_id": [
                            {
                                "identifier": None,
                                "type": None
                            }
                        ]
                    }
                ]
            },

            {
                "dataset_id": {
                    "identifier": None,
                    "type": None
                },
                "title": "Fetal and placental MRI data",
                "description": "MRI data include regional fetal brain MRI measures, placental oxygenation measures, and MR oximetry. MRI data will be captured by each site into the Central Neuroimaging Data Archive at WUSTL.",
                "type": "MRI imaging",
                "issued": None,
                "language": None,
                "keyword": [
                    "fetal brain MRI",
                    "placental MRI",
                    "MR oximetry",
                    "OpenNeuro",
                    "BIDS"
                ],
                "is_reused": None,
                "personal_data": "yes",
                "sensitive_data": "yes",
                "preservation_statement": "MRI data will be preserved and shared via OpenNeuro after images are defaced. Raw data will not be shared due to the potential risk of identifying the fetus.",
                "data_quality_assurance":"Datasets are audited systematically to ensure that the bits are maintained exactly as deposited, and a log of preservation actions is kept to help ensure the content’s integrity.",            
                "security_and_privacy": [
                    {
                        "title": "Defacing and raw data restriction",
                        "description": "MRI data will be shared via OpenNeuro after images are defaced. Raw data will not be shared due to the potential risk of identifying the fetus."
                    }
                ],
                "rights": None,
                "alternate_identifier": [
                    {
                        "identifier": None,
                        "type": None
                    }
                ],
                "creator": [
                    {
                        "name": "Cynthia Ortinau",
                        "mbox": None,
                        "creator_id": {
                            "identifier": "0000-0003-0851-0796",
                            "type": "orcid"
                        },
                        "affiliation": [
                            {
                                "name": "Washington University in St. Louis",
                                "affiliation_id": {
                                    "identifier": None,
                                    "type": None
                                }
                            }
                        ]
                    }
                ],
                
                "distribution": [
                    {
                        "title": "MRI data distribution via OpenNeuro",
                        "description": "MRI data will be deposited into OpenNeuro. Digital content ingested to OpenNeuro is replicated multiple times and stored in geo-diverse locations on different media types. Changes to content can be tracked and snapshots can be made that uniquely identify specific points in the lifetime of each dataset. Metadata describing each dataset snapshot is indexed for searching, and persistent DOIs are minted for each version.",
                        "access_url": None,
                        "available_until": None,
                        "byte_size": None,
                        "data_access": "controlled",
                        "download_url": None,
                        "format": [],
                        "issued": None,
                        "license": [
                            {
                                "license_ref": "CC0",
                                "start_date": "36 months after the first successful version of the dataset"
                            }
                        ],
                        "host": {
                            "title": "OpenNeuro",
                            "url": None,
                            "description": "OpenNeuro replicates data multiple times in geo-diverse locations on different media types, audits datasets systematically, and uses widely adopted and actively maintained open-source data management tools.",
                            "availability": "long-term",
                            "backup_frequency": None,
                            "backup_type": "replicated multiple times in geo-diverse locations on different media types",
                            "certified_with": None,
                            "geo_location": None,
                            "host_id": {
                                "identifier": None,
                                "type": None
                            },
                            "pid_system": "DOI",
                            
                            "storage_type": "repository",
                            "support_versioning": "yes"
                        }
                    }
                ],
                "metadata": [
                    {
                        "description": "MRI data will be standardized using the Brain Imaging Data Structure (BIDS) recommendations.",
                        "language": None,
                        "metadata_standard_id": [
                            {
                                "identifier": "Brain Imaging Data Structure (BIDS)",
                                "type": "standard"
                            }
                        ]
                    }
                ],
                "related_identifier": [
                    {
                        "identifier": None,
                        "type": None,
                        "relation_type": None,
                        "metadata_scheme": None,
                        "scheme_uri": None,
                        "scheme_type": None,
                        "resource_type": None
                    }
                ],
                "technical_resource": [
                    {
                        "name": "Fetal brain analysis software",
                        "description": "The software and algorithms used for fetal brain analysis are distributed as open source software and are shared through a GitHub repository (bchimagine).",
                        "technical_resource_id": [
                            {
                                "identifier": "bchimagine",
                                "type": "github_repository"
                            }
                        ]
                    },
                    {
                        "name": "Placental MRI methods",
                        "description": "Placental MRI methods are also readily available and can be provided by contacting the research team.",
                        "technical_resource_id": [
                            {
                                "identifier": None,
                                "type": None
                            }
                        ]
                    }
                ]
            },

            {
                "dataset_id": {
                    "identifier": None,
                    "type": None
                },
                "title": "Genomic data",
                "description": "Genomic data will be individual level data. Analysis of genomic DNA will link genotype to phenotypic information obtained as part of this study. Genomic data will include trio whole exome sequencing (WES).",
                "type": "genomic",
                "issued": None,
                "language": None,
                "keyword": [
                    "genomic data",
                    "whole exome sequencing",
                    "WES",
                    "dbGaP",
                    "CRAM",
                    "VCF"
                ],
                "is_reused": None,
                "personal_data": "yes",
                "sensitive_data": "yes",
                "preservation_statement": "The study will be registered in dbGaP at the time of data cleaning and quality control measure initiation. Genomic data will be shared and deposited into dbGaP according to GDS policy, which requires that genomic data must be submitted within 3 months following data generation and released within 6 months of data submission to the repository or at acceptance of the publication, whichever is first.",
                "data_quality_assurance": None,
              
                "security_and_privacy": [
                    {
                        "title": "Controlled access for individual-level data",
                        "description": "For dbGaP, summary level data is open but credentialed users must apply for access to individual-level data."
                    }
                ],
                "rights": None,
                "alternate_identifier": [
                    {
                        "identifier": None,
                        "type": None
                    }
                ],
                "creator": [
                    {
                        "name": "Cynthia Ortinau",
                        "mbox": None,
                        "creator_id": {
                            "identifier": "0000-0003-0851-0796",
                            "type": "orcid"
                        },
                        "affiliation": [
                            {
                                "name": "Washington University in St. Louis",
                                "affiliation_id": {
                                    "identifier": None,
                                    "type": None
                                }
                            }
                        ]
                    }
                ],
                
                "distribution": [
                    {
                        "title": "Genomic data distribution via dbGaP",
                        "description": "WES and phenotype data will be uploaded using in dbGaP according to GDS policy and templates. Datasets in dbGaP will be findable through the study accession number, a unique, stable, and versioned identifier.",
                        "access_url": None,
                        "available_until": None,
                        "byte_size": 21990232555520,
                        "data_access": "controlled",
                        "download_url": None,
                        "format": [
                            "CRAM",
                            "VCF"
                        ],
                        "issued": None,
                        "license": [
                            {
                                "license_ref": None,
                                "start_date": None
                            }
                        ],
                        "host": {
                            "title": "dbGaP",
                            "url": None,
                            "description": "The study will be registered in dbGaP at the time of data cleaning and quality control measure initiation. Genomic data will be shared and deposited into dbGaP according to GDS policy.",
                            "availability": None,
                            "backup_frequency": None,
                            "backup_type": None,
                            "certified_with": None,
                            "geo_location": None,
                            "host_id": {
                                "identifier": None,
                                "type": None
                            },
                            "pid_system":  "study accession number",
                            "storage_type": "repository",
                            "support_versioning": "yes"
                        }
                    }
                ],
                "metadata": [
                    {
                        "description": "Genomic data will be in CRAM format with alignment to the latest reference genome and variant files in VCF format. Common Data Elements will be applied as relevant using the NICHD data standards.",
                        "language": None,
                        "metadata_standard_id": [
                            {
                                "identifier": "NICHD data standards",
                                "type": "standard"
                            }
                        ]
                    }
                ],
                "related_identifier": [
                    {
                        "identifier": None,
                        "type": None,
                        "relation_type": None,
                        "metadata_scheme": None,
                        "scheme_uri": None,
                        "scheme_type": None,
                        "resource_type": None
                    }
                ],
                "technical_resource": [
                    {
                        "name": None,
                        "description": None,
                        "technical_resource_id": [
                            {
                                "identifier": None,
                                "type": None
                            }
                        ]
                    }
                ]
            },

            {
                "dataset_id": {
                    "identifier": None,
                    "type": None
                },
                "title": "Placental tissue data",
                "description": "Placental tissue data include qualitative clinical assessment and confocal laser scanning microscopy. Placental tissue will be maintained in the Pathology Department at WUSTL, with additional slides for confocal laser scanning microscopy maintained in a secure laboratory environment managed by one of the co-investigators.",
                "type": "placental tissue; microscopy",
                "issued": None,
                "language": None,
                "keyword": [
                    "placental tissue",
                    "confocal laser scanning microscopy",
                    "REDCap"
                ],
                "is_reused": None,
                "personal_data": "yes",
                "sensitive_data": "yes",
                "preservation_statement": "Placental data entered into the REDCap EDC system will be cleaned, de-identified, preserved and shared.",
                "data_quality_assurance": None,
                "security_and_privacy": [
                    {
                        "title": "Secure laboratory environment",
                        "description": "Additional slides for confocal laser scanning microscopy will be maintained in a secure laboratory environment managed by one of the co-investigators."
                    }
                ],
                "rights": "Data will be made publicly available with controlled access under Data Use Agreement to ensure the safety of participants' data.",
                "alternate_identifier": [
                    {
                        "identifier": None,
                        "type": None
                    }
                ],
                "creator": [
                    {
                        "name": "Cynthia Ortinau",
                        "mbox": None,
                        "creator_id": {
                            "identifier": "0000-0003-0851-0796",
                            "type": "orcid"
                        },
                        "affiliation": [
                            {
                                "name": "Washington University in St. Louis",
                                "affiliation_id": {
                                    "identifier": None,
                                    "type": None
                                }
                            }
                        ]
                    }
                ],
                
                "distribution": [
                    {
                        "title": "Placental tissue data distribution",
                        "description": "All de-identified placental tissue data will be shared via the institutional repository Digital Commons@Becker.",
                        "access_url": None,
                        "available_until": None,
                        "byte_size": None,
                        "data_access": "controlled",
                        "download_url": None,
                        "format": [],
                        "issued": None,
                        "license": [
                            {
                                "license_ref": None,
                                "start_date": None
                            }
                        ],
                        "host": {
                            "title": "Digital Commons@Becker",
                            "url": None,
                            "description": "Institutional repository for presenting and preserving the scholarly work created at Washington University School of Medicine in St. Louis.",
                            "availability": "long-term",
                            "backup_frequency": None,
                            "backup_type": "S3 cloud storage backup",
                            "certified_with": None,
                            "geo_location": None,
                            "host_id": {
                                "identifier": "DigitalCommons@Becker",
                                "type": None
                            },
                            "pid_system": "DOI",
                            "storage_type": "repository",
                            "support_versioning": None
                        }
                    }
                ],
                "metadata": [
                    {
                        "description": "A data dictionary will be generated and deposited into a repository along with all shared datasets. A README file will also be generated and deposited into the repository and will include instructions for data analysis.",
                        "language": None,
                        "metadata_standard_id": [
                            {
                                "identifier": None,
                                "type": None
                            }
                        ]
                    }
                ],
                "related_identifier": [
                    {
                        "identifier": None,
                        "type": None,
                        "relation_type": None,
                        "metadata_scheme": None,
                        "scheme_uri": None,
                        "scheme_type": None,
                        "resource_type": None
                    }
                ],
                "technical_resource": [
                    {
                        "name": None,
                        "description": None,
                        "technical_resource_id": [
                            {
                                "identifier": None,
                                "type": None
                            }
                        ]
                    }
                ]
            }
        ],

        "alternate_identifier": [
            {
                "identifier": None,
                "type": None
            }
        ],

        "related_identifier": [
            {
                "identifier": "https://grants.nih.gov/grants/guide/pa-files/PA-20-185.html",
                "type": "url",
                "relation_type": "IsReferencedBy",
                "metadata_scheme": None,
                "scheme_uri": None,
                "scheme_type": None,
                "resource_type": "Grant"
            }
        ]
    }
}

# %%
# Step 3 — save the example maDMP instance
with open("dmp1_original.json", "w", encoding="utf-8") as f:
    json.dump(dmp1_original, f, indent=2, ensure_ascii=False)

print("Saved: dmp1_original.json")
# Out:
# Saved: dmp1_original.json

# %%
dmp1_new_version = {
  "$schema": "./JSON-schema/1.2/maDMP-schema-1.2.json",
  "dmp": {
    "dmp_id": {
      "identifier": "https://doi.org/10.48321/D1BS7N",
      "type": "DOI"
    },
    "title": "Effects of Placental Dysfunction on Brain Growth in Congenital Heart Disease",
    "description": None,
    "created": None,
    "modified": "01-24-2024",
    "language": "en",
    "ethical_issues_exist": "yes",
    "ethical_issues_description": "Privacy, rights, and confidentiality of participants will be protected as outlined in NOT-OD-22-213, including whether scientific data will be shared using access controls.",
    "ethical_issues_report": None,

    "contact": {
      "name": "Cynthia Ortinau",
      "mbox": None,
      "contact_id": {
        "identifier": "0000-0003-0851-0796",
        "type": "ORCID"
      },
      "affiliation": [
        {
          "name": "Washington University in St. Louis",
          "affiliation_id": {
            "identifier": None,
            "type": None
          }
        }
      ]
    },

    "contributor": [
      {
        "name": "Cynthia Ortinau",
        "mbox": None,
        "role": [],
        "contributor_id": {
          "identifier": "0000-0003-0851-0796",
          "type": "ORCID"
        },
        "affiliation": [
          {
            "name": "Washington University in St. Louis",
            "affiliation_id": {
              "identifier": None,
              "type": None
            }
          }
        ]
      }
    ],

    "cost": [
      {
        "title": None,
        "description": None,
        "value": None,
        "currency_code": None
      }
    ],

    "project": [
      {
        "title": "Effects of Placental Dysfunction on Brain Growth in Congenital Heart Disease",
        "description": None,
        "start": "09-01-2023",
        "end": "08-31-2028",
        "project_id": [
          {
            "identifier": None,
            "type": None
          }
        ],
        "funding": [
          {
            "funder_name": "National Institutes of Health",
            "funder_id": {
              "identifier": None,
              "type": None
            },
            "grant_id": {
              "identifier": None,
              "type": None
            },
            "funding_status": None
          }
        ]
      }
    ],

    "dataset": [

      {
        "dataset_id": {
          "identifier": None,
          "type": None
        },
        "title": "Human demographic and clinical data",
        "description": None,
        "type": None,
        "issued": None,
        "language": None,
        "keyword": [],
        "is_reused": False,
        "personal_data": "yes",
        "sensitive_data": None,
        "preservation_statement": None,
        "data_quality_assurance": None,

        "security_and_privacy": [
          {
            "title": None,
            "description": None
          }
        ],

        "rights": None,
        "alternate_identifier": [
          {
            "identifier": None,
            "type": None
          }
        ],

        "creator": [
          {
            "name": None,
            "mbox": None,
            "creator_id": {
              "identifier": None,
              "type": None
            },
            "affiliation": [
              {
                "name": None,
                "affiliation_id": {
                  "identifier": None,
                  "type": None
                }
              }
            ]
          }
        ],

        "distribution": [
          {
            "title": "DigitalCommons@Becker",
            "description": None,
            "access_url": None,
            "available_until": None,
            "byte_size": 0,
            "data_access": None,
            "download_url": None,
            "format": [],
            "issued": None,
            "license": [
              {
                "license_ref": None,
                "start_date": None
              }
            ],

            "host": {
              "title": "DigitalCommons@Becker",
              "url": None,
              "description": None,
              "availability": None,
              "backup_frequency": None,
              "backup_type": None,
              "certified_with": None,
              "geo_location": None,

              "host_id": {
                "identifier": None,
                "type": None
              },
              "pid_system": None,
              "storage_type": None,
              "support_versioning": None
            }
          }
        ],

        "metadata": [
          {
            "description": None,
            "language": None,

            "metadata_standard_id": [
              {
                "identifier": None,
                "type": None
              }
            ]
          }
        ],

        "related_identifier": [
          {
            "identifier": None,
            "type": None,
            "relation_type": None,
            "metadata_scheme": None,
            "scheme_uri": None,
            "scheme_type": None,
            "resource_type": None
          }
        ],

        "technical_resource": [
          {
            "name": None,
            "description": None,
            "technical_resource_id": [
              {
                "identifier": None,
                "type": None
              }
            ]
          }
        ]
      },
      {
        "dataset_id": {
          "identifier": None,
          "type": None
        },
        "title": "Human fetal and placental MRI imaging data",
        "description": None,
        "type": None,
        "issued": None,
        "language": None,
        "keyword": [],
        "is_reused": False,
        "personal_data": "yes",
        "sensitive_data": None,
        "preservation_statement": None,
        "data_quality_assurance": None,

        "security_and_privacy": [
          {
            "title": None,
            "description": None
          }
        ],

        "rights": None,
        "alternate_identifier": [
          {
            "identifier": None,
            "type": None
          }
        ],

        "creator": [
          {
            "name": None,
            "mbox": None,
            "creator_id": {
              "identifier": None,
              "type": None
            },

            "affiliation": [
              {
                "name": None,
                "affiliation_id": {
                  "identifier": None,
                  "type": None
                }
              }
            ]
          }
        ],

        "distribution": [
          {
            "title": "OpenNeuro",
            "description": None,
            "access_url": None,
            "available_until": None,
            "byte_size": None,
            "data_access": None,
            "download_url": None,
            "format": [],
            "issued": None,
            "license": [
              {
                "license_ref": None,
                "start_date": None
              }
            ],

            "host": {
              "title": "OpenNeuro",
              "url": None,
              "description": None,
              "availability": None,
              "backup_frequency": None,
              "backup_type": None,
              "certified_with": None,
              "geo_location": None,
              "host_id": {
                "identifier": None,
                "type": None
              },

              "pid_system": [],
              "storage_type": None,
              "support_versioning": None
            }
          }
        ],

        "metadata": [
          {
            "description": None,
            "language": None,
            "metadata_standard_id": [
              {
                "identifier": None,
                "type": None
              }
            ]
          }
        ],

        "related_identifier": [
          {
            "identifier": None,
            "type": None,
            "relation_type": None,
            "metadata_scheme": None,
            "scheme_uri": None,
            "scheme_type": None,
            "resource_type": None
          }
        ],

        "technical_resource": [
          {
            "name": None,
            "description": None,
            "technical_resource_id": [
              {
                "identifier": None,
                "type": None
              }
            ]
          }
        ]
      },

      {
        "dataset_id": {
          "identifier": None,
          "type": None
        },

        "title": "Human genomic data (whole exome sequencing)",
        "description": None,
        "type": None,
        "issued": None,
        "language": None,
        "keyword": [],
        "is_reused": False,
        "personal_data": "yes",
        "sensitive_data": None,
        "preservation_statement": None,
        "data_quality_assurance": None,
        "security_and_privacy": [
          {
            "title": None,
            "description": None
          }
        ],

        "rights": None,
        "alternate_identifier": [
          {
            "identifier": None,
            "type": None
          }
        ],

        "creator": [
          {
            "name": None,
            "mbox": None,
            "creator_id": {
              "identifier": None,
              "type": None
            },

            "affiliation": [
              {
                "name": None,
                "affiliation_id": {
                  "identifier": None,
                  "type": None
                }
              }
            ]
          }
        ],

        "distribution": [
          {
            "title": "dbGaP",
            "description": None,
            "access_url": None,
            "available_until": None,
            "byte_size": None,
            "data_access": None,
            "download_url": None,
            "format": [],
            "issued": None,
            "license": [
              {
                "license_ref": None,
                "start_date": None
              }
            ],

            "host": {
              "title": "dbGaP",
              "url": None,
              "description": None,
              "availability": None,
              "backup_frequency": None,
              "backup_type": None,
              "certified_with": None,
              "geo_location": None,
              "host_id": {
                "identifier": None,
                "type": None
              },

              "pid_system": None,
              "storage_type": None,
              "support_versioning": None
            }
          }
        ],

        "metadata": [
          {
            "description": None,
            "language": None,
            "metadata_standard_id": [
              {
                "identifier": None,
                "type": None
              }
            ]
          }
        ],

        "related_identifier": [
          {
            "identifier": None,
            "type": None,
            "relation_type": None,
            "metadata_scheme": None,
            "scheme_uri": None,
            "scheme_type": None,
            "resource_type": None
          }
        ],

        "technical_resource": [
          {
            "name": None,
            "description": None,
            "technical_resource_id": [
              {
                "identifier": None,
                "type": None
              }
            ]
          }
        ]
      },


      {
        "dataset_id": {
          "identifier": None,
          "type": None
        },

        "title": "Placental tissue microscopy data",
        "description": None,
        "type": None,
        "issued": None,
        "language": None,
        "keyword": [],
        "is_reused": False,
        "personal_data": "yes",
        "sensitive_data": None,
        "preservation_statement": None,
        "data_quality_assurance": None,
        "security_and_privacy": [
          {
            "title": None,
            "description": None
          }
        ],

        "rights": None,
        "alternate_identifier": [
          {
            "identifier": None,
            "type": None
          }
        ],

        "creator": [
          {
            "name": None,
            "mbox": None,
            "creator_id": {
              "identifier": None,
              "type": None
            },

            "affiliation": [
              {
                "name": None,
                "affiliation_id": {
                  "identifier": None,
                  "type": None
                }
              }
            ]
          }
        ],

        "distribution": [
          {
            "title": "DigitalCommons@Becker",
            "description": None,
            "access_url": None,
            "available_until": None,
            "byte_size": 0,
            "data_access": None,
            "download_url": None,
            "format": [],
            "issued": None,
            "license": [
              {
                "license_ref": None,
                "start_date": None
              }
            ],

            "host": {
              "title": "DigitalCommons@Becker",
              "url": None,
              "description": None,
              "availability": None,
              "backup_frequency": None,
              "backup_type": None,
              "certified_with": None,
              "geo_location": None,
              "host_id": {
                "identifier": None,
                "type": None
              },

              "pid_system": None,
              "storage_type": None,
              "support_versioning": None
            }
          }
        ],

        "metadata": [
          {
            "description": None,
            "language": None,
            "metadata_standard_id": [
              {
                "identifier": None,
                "type": None
              }
            ]
          }
        ],

        "related_identifier": [
          {
            "identifier": None,
            "type": None,
            "relation_type": None,
            "metadata_scheme": None,
            "scheme_uri": None,
            "scheme_type": None,
            "resource_type": None
          }
        ],

        "technical_resource": [
          {
            "name": None,
            "description": None,
            "technical_resource_id": [
              {
                "identifier": None,
                "type": None
              }
            ]
          }
        ]
      }

    ],

    "alternate_identifier": [
      {
        "identifier": None,
        "type": None
      }
    ],

    "related_identifier": [
      {
        "identifier": None,
        "type": None,
        "relation_type": None,
        "metadata_scheme": None,
        "scheme_uri": None,
        "scheme_type": None,
        "resource_type": None
      }
    ]
  }
}

# %%
# Step 3 — save the example maDMP instance
with open("dmp1_new_version.json", "w", encoding="utf-8") as f:
    json.dump(dmp1_new_version, f, indent=2, ensure_ascii=False)

print("Saved: dmp1_new_version.json")
# Out:
# Saved: dmp1_new_version.json
